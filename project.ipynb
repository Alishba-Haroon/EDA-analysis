# %% [markdown]
#  # Importing libraries

# %%
# importing libaries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading the dataset

# %%
# file import
df = pd.read_excel(r"") # file path

# %% [markdown]
# # Exploratory Data Analysis and Data Cleaning

# %%
# show Total columns
df.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
# show Total columns
df.tail()
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
#       Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 1947    Andrea Shaw  Regular Air   Small Business  Office Supplies  ...
# 1948    Andrea Shaw  Regular Air   Small Business       Technology  ...
# 1949    Marvin Reid  Regular Air   Small Business  Office Supplies  ...
# 1950  Florence Gold  Express Air   Small Business        Furniture  ...
# 1951  Tammy Buckley  Express Air         Consumer        Furniture  ...
#
# ...

# %%
# Total numbers of columns and rows
df.shape
# Out:
# (1952, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
# Show null values in dataset as True or False
pd.isnull(df)
# Out:
#       Row ID  Order Priority  Discount  Unit Price  Shipping Cost  \
# 0      False           False     False       False          False
# 1      False           False     False       False          False
# 2      False           False     False       False          False
# 3      False           False     False       False          False
# 4      False           False     False       False          False
# ...      ...             ...       ...         ...            ...
# 1947   False           False     False       False          False
# 1948   False           False     False       False          False
# 1949   False           False     False       False          False
# 1950   False           False     False       False          False
# 1951   False           False     False       False          False
#
#       Customer ID  Customer Name  Ship Mode  Customer Segment  \
# 0           False          False      False             False
# ...

# %%
# Check which columns have null values
pd.isnull(df).sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
# Total Rows and Columns
df.shape
# Out:
# (1952, 25)

# %%
# Removing null values
df.dropna(inplace=True)
# Total numbers of Row and columns after remove null values
df.shape
# Out:
# (1936, 25)

# %%
# Changing the datatype
df['Sales'] = df['Sales'].astype('int')

# %%
# checking the datatype
df['Sales'].dtypes
# Out:
# dtype('int32')

# %%
# show Total columns names
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
# Describing the Dataset
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1936.000000  1936.000000  1936.000000    1936.000000  1936.000000
# mean   19917.548554     0.048858   108.034685      12.783280  1733.831095
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.032500   874.000000
# 50%    21167.500000     0.050000    20.990000       6.095000  1738.000000
# 75%    23499.750000     0.070000    99.230000      14.000000  2578.000000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
# std     5968.385953     0.031340   394.836173      17.289631   990.512340
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          1936.000000   1936.000000                           1936
# mean              0.515186  51545.004132  2015-03-29 01:14:22.809917440
# min               0.350000   1001.000000            2015-01-01 00:00:00
# ...

# %%
# For specific columns describe
df[['Discount', 'Sales', 'Profit']].describe()
# Out:
#           Discount         Sales        Profit
# count  1936.000000   1936.000000   1936.000000
# mean      0.048858    971.358471    111.065806
# std       0.031340   2559.355713   1136.352380
# min       0.000000      2.000000 -16476.838000
# 25%       0.020000     58.000000    -83.675000
# 50%       0.050000    200.000000      1.300200
# 75%       0.070000    774.500000    113.473725
# max       0.210000  45737.000000   9228.225600

# %% [markdown]
# # Data Analysis and Visualizations

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
# Countplot Graph of Order Priority
ax = sns.countplot(x = 'Order Priority',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Countplot of Discount
ax = sns.countplot(data = df, x ='Discount', hue = 'Discount')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Barplot of Sales or Profit
new_Profit = df.groupby(['Sales'], as_index=False)['Profit'].sum().sort_values(by='Profit',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = new_Profit, x = 'Sales',y='Profit')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
# Barplot of Unit Price and Shipping Cost
new_Profit = df.groupby(['Unit Price'], as_index=False)['Shipping Cost'].sum().sort_values(by='Shipping Cost',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = new_Profit, x = 'Unit Price',y='Shipping Cost')
# Out:
# <Axes: xlabel='Unit Price', ylabel='Shipping Cost'>

# %%
# Line Plot
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x='Quantity ordered new', y='Product Base Margin')
plt.title('Line Plot')
plt.xlabel('Quantity ordered new')
plt.ylabel('Product Base Margin')
plt.show()

# %%
# Assuming you have a DataFrame df with columns 'Region'

# Calculate the count of each unique value in the 'Region' column
region_counts = df['Region'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Region Distribution')
plt.show()

# %%
# Plotting the histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Order Date')
plt.title('Histogram of Order Dates')
plt.xlabel('Order Date')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting the jointplot
sns.jointplot(data=df, x='Region', y='Product Container', kind='hist')
plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# The EDA analysis of the superstore dataset highlights sales distribution, seasonal trends, customer segmentation, profitability, supply chain optimization, outlier detection, and correlation analysis. These insights inform strategic decisions to improve operational efficiency, marketing strategies, and customer satisfaction.
